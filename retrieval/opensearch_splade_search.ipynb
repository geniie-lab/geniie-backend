# %% [markdown]
# # Retrieval of indexed documents based on SPLADE via OpenSearch

# %% [markdown]
# #### Configuration

# %%
index_name = "ntcir1_splade"
model_id = "your-model-id"  # sparse encoding model registered in OpenSearch
q = "情報検索システム"
dataset_name = "ntcir1-adhoc"

# %%
import sys
# !{sys.executable} -m pip install -q ir_datasets opensearch-py dotenv

# %%
import pprint

# %% [markdown]
# Your opensearch password should be available in `~/.env`
#
# ```bash
#     OPENSEARCH_INITIAL_ADMIN_PASSWORD="strong password"
# ```

# %%
import os
from dotenv import load_dotenv
from opensearchpy import OpenSearch

load_dotenv()
host = 'localhost'
port = 9200
password = os.getenv("OPENSEARCH_INITIAL_ADMIN_PASSWORD")

client = OpenSearch(
    hosts=[{"host": host, "port": port}],
    http_auth=("admin", password),
    http_compress=True,
    use_ssl=True,
    verify_certs=False,
    ssl_assert_hostname=False,
    ssl_show_warn=False
)
pprint.pprint(client.info())

# %% [markdown]
# #### SPLADE Search
#
# Documents were chunked and sparse-encoded per passage into the nested `text_chunks_embedding` field. A `neural_sparse` query encodes the query text server-side with `model_id`, and the `nested` wrapper scores each passage — `score_mode: max` keeps the best-matching chunk per document.

# %%
def search(query: str, size: int = 10) -> dict:
    body = {
        "size": size,
        "query": {
            "nested": {
                "path": "text_chunks_embedding",
                "score_mode": "max",  # best-matching passage sets the doc score
                "query": {
                    "neural_sparse": {
                        "text_chunks_embedding.sparse_encoding": {
                            "query_text": query,
                            "model_id": model_id
                        }
                    }
                }
            }
        },
    }

    return client.search(index=index_name, body=body)

# %%
resp = search(q, size=5)

print(f"\nTop {len(resp['hits']['hits'])} hits for query: {q}\n")
for hit in resp["hits"]["hits"]:
    src = hit["_source"]
    print(f"[{src['docid']}] {src['title'][:50]}... (score={hit['_score']:.2f})")

# %% [markdown]
# #### Search with a Topic from the Dataset
#
# Load the dataset registered under `dataset_name` and run SPLADE search for its first topic.

# %%
import importlib
import ir_datasets

# Register the local dataset module (e.g. "ntcir1-adhoc" -> ntcir1_adhoc.py)
sys.path.append(os.path.join(os.getcwd(), '..', 'dataset', dataset_name))
importlib.import_module(dataset_name.replace('-', '_'))

dataset = ir_datasets.load(dataset_name)

# %%
# Grab the first topic from the dataset
topic = next(dataset.queries_iter())
pprint.pprint(topic)

# %%
topic_query = topic.title
resp = search(topic_query, size=5)

print(f"\nTop {len(resp['hits']['hits'])} hits for topic {topic.query_id}: {topic_query}\n")
for hit in resp["hits"]["hits"]:
    src = hit["_source"]
    print(f"[{src['docid']}] {src['title'][:50]}... (score={hit['_score']:.2f})")
